# %%
## Imports
import pandas as pd
import numpy as np
import os

# %%
corpora_path = os.path.realpath('es-corpora/train/')

# %%
# In this dataframe an new sentence is preceded by a row where the columns values is NaN except the first sentence
df = pd.read_csv(corpora_path + '/spanish_tagged_with_features_03.csv', low_memory=False)
df.head(15)
# Out:
#         token      lemma  pos_tag      sense  tag      emission transition  \
# 0    Arequipa   arequipa  NP00000        0.0   NP   Arequipa|NP        NP|
# 1          es        ser  VSIP3S0  1775973.0   VS         es|VS      VS|NP
# 2          el         el   DA0MS0        0.0   DA         el|DA      DA|VS
# 3      nombre     nombre  NCMS000  4778525.0   NC     nombre|NC      NC|DA
# 4          de         de    SPS00        0.0   SP         de|SP      SP|NC
# 5          el         el   DA0MS0        0.0   DA         el|DA      DA|SP
# 6   asteroide  asteroide  NCMS000  6755791.0   NC  asteroide|NC      NC|DA
# 7      número     número  NCMS000  3990394.0   NC     número|NC      NC|NC
# 8         737        737        Z        0.0    Z         737|Z       Z|NC
# 9          de         de    SPS00        0.0   SP         de|SP       SP|Z
# 10         la         el   DA0FS0        0.0   DA         la|DA      DA|SP
# 11      serie      serie  NCFS000  6246946.0   NC      serie|NC      NC|DA
# 12          .          .       Fp        0.0   Fp          .|Fp      Fp|NC
# 13        NaN        NaN      NaN        NaN  NaN           NaN        NaN
# 14   Conocido    conocer  VMP00SM   401762.0   VM   Conocido|VM        VM|
#
#    category type
# 0         N    P
# 1         V    S
# 2         D    A
# 3         N    C
# 4         S    P
# 5         D    A
# 6         N    C
# 7         N    C
# 8         Z  NaN
# 9         S    P
# 10        D    A
# 11        N    C
# 12        F  NaN
# 13      NaN  NaN
# 14        V    M

# %%
# First, lets get the initial state indexes, the index were each sentence starts
init_state_indexes = np.array(df.loc[pd.isna(df['token'])].index.values)
init_state_indexes
# Out:
# array([     13,      71,      74, ..., 5032545, 5032549, 5032557])

# %%
# Now lets create a list of numpy array, those arrays will have the tokens of the sentences 
sentences_array = []
sentences_array.append(df['token'][:init_state_indexes[0]].to_numpy()) 
i = 0
j = i + 1

while j < init_state_indexes.shape[0]:
    sentences_array.append(df['token'][init_state_indexes[i]+1:init_state_indexes[j]].to_numpy())
    i += 1
    j += 1
sentences_array
# Out:
# [array(['Arequipa', 'es', 'el', 'nombre', 'de', 'el', 'asteroide',
#         'número', '737', 'de', 'la', 'serie', '.'], dtype=object),
#  array(['Conocido', 'previamente', 'con', 'la', 'designación',
#         'provisional', '1912', 'QB', 'y', 'la', 'adicional', '1961', 'JH',
#         'el', 'asteroide', '(', '737', ')', 'fue', 'descubierto', 'en',
#         'Winchester', 'de', '7 de diciembre de 1912', 'por',
#         'J.H. Metcalf', 'y', 'bautizado', 'en', 'honor', 'de', 'la',
#         'ciudad', 'peruana', 'en', 'la', 'cual', 'funcionó', 'de', '1889',
#         'a', '1927', 'el', 'Observatorio Boyden', ',', 'una',
#         'instalación', 'de', 'observación', 'de', 'el', 'hemisferio',
#         'sur', 'de', 'el', 'Harvard College Observatory', '.'],
#        dtype=object),
#  array(['ENDOFARTICLE', '.'], dtype=object),
#  array(['La', 'provincia', 'de', 'Teherán', '(', 'Farsi', ':', ')', 'es',
#         'una', 'de', 'las', '30', 'provincias', 'de', 'Irán', ',', 'tiene',
#         'cerca', 'de', '12 millones', 'de', 'habitantes', 'y', 'es', 'la',
#         'provincia', 'más', 'densamente', 'problada', 'de', 'Irán', '.'],
#        dtype=object),
#  array(['Tiene', 'una', 'extensión', 'de', 'alrededor de', '18.637', 'km²',
#         'y', 'se', 'encuentra', 'a', 'el', 'norte', 'de', 'la', 'meseta',
#         'central', 'iraní', '.'], dtype=object),
#  array(['La', 'provincia', 'de', 'Teherán', 'limita', 'con', 'las',
#         'provincias', 'de', 'Mazandarán', 'a', 'el', 'norte', ',', 'Qom',
#         'a', 'el', 'sur', ',', 'Semnán', 'a', 'el', 'este', 'y', 'Qazvin',
#         'a', 'el', 'oeste', '.'], dtype=object),
#  array(['La', 'ciudad', 'de', 'Teherán', 'es', 'la', 'capital', 'tanto',
#         'de', 'la', 'provincia', 'como', 'de', 'el', 'país', ',', 'siendo',
#         'el', 'distrito', 'central', 'de', 'la', 'provincia', '.'],
#        dtype=object),
#  array(['Otros', 'distritos', 'son', ':', 'Shemiranat', ',', 'Rey', ',',
#         'Islam Shahr', ',', 'la', 'ciudad', 'de', 'Ray', ',', 'Karaj', ',',
#         'Jajrood', ',', 'Lar', ',', 'y', 'Rood Shoor', '.'], dtype=object),
#  array(['La', 'provincia', 'alcanzó', 'su', 'importancia', 'cuando',
#         'Teherán', 'sustituyó', ',', 'como', 'capital', ',', 'a', 'Ghajar',
#         'en', '1778', 'con', 'la', 'dinastía', 'Kayar', '.'], dtype=object),
#  array(['Hoy', 'en', 'día', '(', '2004', ')', 'Teherán', 'se', 'encuentra',
#         'entre', 'las', '20', 'ciudades', 'más', 'grandes', 'de', 'el',
#         'mundo', '.'], dtype=object),
#  array(['Geografía', '.'], dtype=object),
#  array(['La', 'provincia', 'de', 'Teherán', 'tiene', 'más', 'de',
#         '14 millones', 'de', 'habitantes', 'y', 'es', 'la', 'región',
#         'más', 'densamente', 'poblada', 'de', 'Irán', '.'], dtype=object),
#  array(['Aproximadamente', 'un', '84,15 %', 'reside', 'en', 'áreas',
#         'urbanas', 'y', 'un', '15,85 %', 'en', 'áreas', 'rurales', 'de',
#         'la', 'provincia', '.'], dtype=object),
#  array(['El', 'punto', 'más', 'alto', 'de', 'la', 'provincia', 'es', 'el',
#         'monte', 'Damavand', ',', 'que', 'llega', 'a', 'los', '5.678',
#         'msnm', ';', 'el', 'punto', 'más', 'bajo', 'de', 'la', 'provincia',
#         'son', 'las', 'llanuras', 'de', 'Varamin', ',', '790', 'msnm', '.'],
#        dtype=object),
#  array(['Los', 'ríos', 'más', 'largos', 'de', 'esta', 'provincia', 'son',
#         'el', 'río', 'Karaj', 'y', 'el', 'río', 'Jajrud', '.'],
#        dtype=object),
#  array(['Las', 'cordilleras', 'como', 'los', 'Elburz', 'cubren', 'el',
#         'norte', ':', 'Savad Kuh', 'y', 'Firuz Kuh', 'se', 'encuentran',
#         'en', 'el', 'noreste', ';', 'Lavasanat', ',', 'Qarah Daq', ',',
#         'Shemiranat', ',', 'Hassan Abad', 'y', 'montañas', 'Namak', 'se',
#         'encuentran', 'en', 'las', 'zonas', 'meridionales', ';',
#         'Bibi Shahr Banu', 'y', 'Alqadr', 'se', 'encuentran', 'en', 'el',
#         'sureste', 'y', 'los', 'altos', 'de', 'Qasr-e-Firuzeh', 'se',
#         'encuentran', 'en', 'la', 'parte', 'este', 'de', 'la', 'provincia',
#         '.'], dtype=object),
#  array(['Hablando', 'desde', 'un', 'punto', 'de', 'vista',
#         'medioambiental', ',', 'el', 'clima', 'de', 'la', 'provincia',
#         'de', 'Teherán', 'en', 'las', 'zonas', 'meridionales', 'es',
#         'cálido', 'y', 'seco', ',', 'pero', 'en las cercanías de', 'las',
#         'montañas', 'es', 'frío', 'y', 'semi-húmedo', ',', 'y', 'en',
#         'las', 'regiones', 'más', 'altas', 'es', 'frío', 'con', 'largos',
#         'inviernos', '.'], dtype=object),
#  array(['Los', 'meses', 'más', 'cálidos', 'de', 'el', 'año', 'son',
#         'desdemediados', 'de', 'julio', 'a mediados de', 'septiembre', ',',
#         'cuando', 'las', 'temperaturas', 'van', 'desde', 'los', '28º', 'a',
#         'los', '30º', 'y', 'los', 'meses', 'más', 'fríos', 'son', 'de',
#         '1ºC', 'alrededor de', 'diciembre-ebnero', ',', 'pero', 'en',
#         'ciertas', 'épocas', 'en', 'invierno', 'puede', 'ser', 'de',
#         '15ºC', 'bajo', 'cero', '.'], dtype=object),
#  array(['La', 'ciudad', 'de', 'Teherán', 'tiene', 'inviernos', 'moderados',
#         'y', 'veranos', 'cálidos', '.'], dtype=object),
#  array(['La', 'pluviosidad', 'media', 'anual', 'es', 'de',
#         'aproximadamente', '200 mm', ',', 'siendo', 'el', 'máximo',
#         'durante', 'la', 'estación', 'invernal', '.'], dtype=object),
#  array(['Historia', '.'], dtype=object),
#  array(['La', 'provincia', 'de', 'Teherán', 'tiene', 'varios',
#         'yacimientos', 'arqueológicos', 'que', 'indican', 'asentamientos',
#         'que', 'se', 'remontan', 'a', 'hace', 'varios', 'miles', 'de',
#         'años', '.'], dtype=object),
#  array(['Hasta', 'hace', 'trescientos', 'años', ',', 'Ray', 'era', 'la',
#         'más', 'destacada', 'de', 'las', 'ciudades', 'de', 'la',
#         'provincia', '.'], dtype=object),
#  array(['Sin', 'embargo', ',', 'la', 'ciudad', 'de', 'Teherán', 'creció',
#         'hasta', 'convertir', 'se', 'en', 'la', 'ciudad', 'más', 'grande',
#         'y', 'capital', 'de', 'Irán', 'para', 'el', 'año 1778', ',', 'y',
#         'desde', 'entonces', 'ha', 'sido', 'el', 'núcleo', 'comercial',
#         ',', 'económico', ',', 'cultural', 'y', 'político', 'de', 'Irán',
#         '.'], dtype=object),
#  array(['Teherán', 'tiene', 'más', 'de', '1.500', 'puntos', 'históricos',
#         'de', 'significado', 'cultural', 'registrado', 'en', 'la',
#         'Organización de el Patrimonio Cultural de Irán', '.'],
#        dtype=object),
#  array(['El', 'más', 'antiguo', 'de', 'éstos', 'en', 'la', 'provincia',
#         'de', 'Teherán', 'son', 'los', 'restos', 'de', 'dos',
#         'yacimientos', 'en', 'el', 'distrito', 'de', 'Firuzkuh', 'que',
#         'se', 'remontan', 'a', 'el', 'IV', 'milenio', 'a', '.'],
#        dtype=object),
#  array(['C. Divisiones', '.'], dtype=object),
#  array(['Distritos', ':', 'Municipios', ':', 'Absard', ',', 'Andishe', ',',
#         'Baghershahr', ',', 'Baghestan', ',', 'Boumehen', ',',
#         'Chahardangeh', ',', 'Damavand', ',', 'Eshtehard', ',',
#         'Eslamshahr', ',', 'Ferdowsieh', ',', 'Firouzkouh', ',',
#         'Garmdarreh', ',', 'Gharchak', ',', 'Ghods', ',', 'Golestan', ',',
#         'Shahriar', ',', 'Hashtgerd', ',', 'Nueva Ciudad de Hashtgerd',
#         ',', 'Javadabad', ',', 'Hassan Abad', ',', 'Kahrizak', ',',
#         'Kamalshahr', ',', 'Karaj', ',', 'Kilan', ',', 'Lavasan', ',',
#         'Mahdasht', ',', 'Malard', ',', 'Meshkindasht', ',',
#         'Mohammadshahr', ',', 'Nasimshahr', ',', 'Nazarbad', ',',
#         'Owshan Fasham Meygoun', ',', 'Pakdasht', ',', 'Pardis', ',',
#         'Pishva', ',', 'Robat Karim', ',', 'Roudehen', ',', 'Sabasharh',
#         ',', 'Safadasht', ',', 'Shahedshahr', ',', 'Shahriar', ',',
#         'Sharifabad', ',', 'Tehran', ',', 'Vahidieh', ',', 'Varamin', ',',
#         'La', 'provincia', 'de', 'Teherán', 'hoy', '.'], dtype=object),
#  array(['Teherán', 'es', 'el', 'corazón', 'comercial', 'de', 'Irán', '.'],
#        dtype=object),
#  array(['La', 'provincia', 'de', 'Teherán', 'tiene', 'alrededor de',
#         '17.000', 'unidades', 'industriales', 'que', 'emplean', 'a',
#         '390.000', 'personas', ',', '26 %', 'de', 'todas', 'las',
#         'unidades', 'de', 'Irán', '.'], dtype=object),
#  array(['La', 'provincia', 'contiene', 'un', '30 %', 'de', 'la',
#         'economía', 'de', 'Irán', 'y', 'comprende', 'el', '40 %', 'de',
#         'el', 'mercado', 'consumidor', 'iraní', '.'], dtype=object),
#  array(['Tiene', 'tres', 'pantanos', 'llamados', 'Latiyan', ',', 'Lar',
#         'y', 'Amir Kabir', 'así como', 'dos', 'lagos', 'naturales', ',',
#         'proporcionando', 'agua', 'para', 'Teherán', 'y', 'su',
#         'provincia', '.'], dtype=object),
#  array(['Contiene', '170', 'minas', ',', 'sobre',
#         '330 kilómetros cuadrados', 'de', 'bosques', 'y', 'más', 'de',
#         '12.800 km2', 'de', 'pastos', '.'], dtype=object),
#  array(['Hablando', 'en', 'general', ',', 'en', 'todo', 'el', 'año', ',',
#         'regiones', 'como', 'las', 'laderas', 'meridionales', 'de', 'los',
#         'montes', 'Elburz', ',', 'especialmente', 'en', 'las', 'montañas',
#         ',', 'valles', 'y', 'ríos', 'y', 'lagos', 'artificiales',
#         'formados', 'tras', 'las', 'grandes', 'presas', 'de', 'Amir Kabir',
#         ',', 'Latiyan', 'y', 'Lar', 'junto con', 'los', 'lagos',
#         'naturales', 'de', 'Jaban', 'y', 'Tarr', 'proporcionan',
#         'considerable', 'recreación', 'para', 'la', 'provincia', '.'],
#        dtype=object),
#  array(['Más', 'aún', ',', 'debido a', 'la', 'excesiva', 'nieve', 'en',
#         'las', 'áreas', 'septentrionales', 'de', 'la', 'provincia',
#         'durante', 'la', 'temporada', 'invernal', ',', 'los', 'Elburz',
#         'forman', 'un', 'excelente', 'ambiente', 'para', 'deportes', 'de',
#         'invierno', 'como', 'el', 'esquí', '.'], dtype=object),
#  array(['Dizin', ',', 'Shemshak', 'y', 'Tochal', 'son', 'las',
#         'estaciones', 'de', 'esquí', 'más', 'populares', '.'], dtype=object),
#  array(['Parques', 'y', 'otras', 'atracciones', '.'], dtype=object),
#  array(['Darband', '(', 'senda', ')', ';', 'Parque Chitgar', ';',
#         'Parque Mellat', ';', 'Parque Laleh', ';', 'Parque Jamshidieh',
#         ';', 'Parque Niavaran', ';', "Parque Sa'ei", ';',
#         'Parque Shatranj', ';', 'Tangeh Savashi', ';', 'Parque de Policía',
#         ';', 'Senda Darabad', ';', 'Senda Darakeh', ';',
#         'Parque Jahan-e Kudak', ';', 'Complejo Deportivo Azadi', ';',
#         'Complejo Deportivo', 'y', 'campo', 'de', 'golf', 'Enghelab', ';',
#         'Varias', 'cuevas', ',', 'manantiales', 'y', 'cascadas',
#         'fuera de', 'Teherán', '.'], dtype=object),
#  array(['Lago Latyan', ';', 'Parque', 'forestal', 'Lavizan', ';', 'Parque',
#         'forestal', 'Vard-Avard', ';', 'Parque Nacional Khajeer', ';',
#         'Parque Nacional Kaveer', ';', 'Lago Tar', ';', 'Lago Amir Kabir',
#         ';', 'Hábitat Natural', 'protegido', 'de', 'Lar', ';',
#         'Hábitat Natural', 'protegido', 'de', 'Varjeen', ';', 'Centros',
#         'religiosos', '.'], dtype=object),
#  array(['Mosquitas', ',', 'santuarios', ',', 'mausoleos', 'y', 'tumbas',
#         '.'], dtype=object),
#  array(['Mezquita Soltani', ',', 'construida', 'por', 'Fath Alí Sah Kayar',
#         ';', 'Mezquita Atiq', ',', 'construida', 'en', '1663', '.'],
#        dtype=object),
#  array(["Mezquita Mo'ezz", 'o-dowleh', ',', 'construida', 'por',
#         'Fath Alí Sah Kayar', ';', 'Mezquita Haj Seyd Azizollah', ',',
#         'construida', 'por', 'Fath Alí Sah Kayar', ';',
#         'Mezquita Al-javad', ',', 'la', 'primera', 'mezquita', 'de',
#         'diseño', 'modernista', 'de', 'Irán', ';', 'La', 'antigua',
#         'mezquita', 'de', 'Sepahsalar', ',', 'otra', 'destacada',
#         'mezquita', 'de', 'la', 'época', 'Kayar', ';', 'La', 'nueva',
#         'mezquita', 'de', 'Sepahsalar', '(', 'Madreseh', 'e', 'Motahari',
#         ')', ';', 'Mezquita Filsuf', 'o-dowleh', ',', 'época', 'Kayar',
#         ';', 'Mezquita Moshir', 'ol-Saltaneh', ',', 'época', 'Kayar', ';',
#         "Mezquita Mo'ayyer", 'ol-Mamalik', ',', 'época', 'Kayar', ';',
#         'Mausoleo de Shahr Banu', ';', 'Mausoleo Javan-mard Qassab', ',',
#         'un', 'héroe', 'preislámico', 'semi-mítico', ';', 'Docenas', 'de',
#         'santuarios', 'de', 'Imam-zadeh', ',', 'con', 'cientos', 'de',
#         'años', 'de', 'antigüedad', ',', 'incluyendo', 'el', 'de',
#         'Imam Zadeh Saleh', '.'], dtype=object),
#  array(['Docenas de Saqa Khanehs', ':', 'tradicionales', 'lugares', 'de',
#         'oración', ';', 'Varios Tekyehs', ':', 'tradicionales', 'lugares',
#         'para', 'ceremonias', 'Muharram', 'de', 'duelo', 'por', 'Husayn',
#         'ibn', 'Ali', '.'], dtype=object),
#  array(['Cementerio Ibn Babviyeh', ',', 'donde', 'están', 'enterrados',
#         'muchos', 'grandes', 'iraníes', ',', 'entre', 'ellos', 'Tajti',
#         'y', 'Ali Akbar Dehjoda', ';', 'Cementerio Zahir', 'o-dowleh', ',',
#         'donde', 'están', 'enterradas', 'figuras', 'de', 'el', 'arte', 'y',
#         'la', 'cultura', 'como', 'Iraj Mirza', ',', 'Muhammad Taghi Bahar',
#         ',', 'Forugh Farrojzad', ',', 'Abolhasan Saba', ',',
#         'Ruhollah Jaleghi', 'y', 'Darvish-khan', ';', 'Tumba Kordan', ',',
#         'selyúcida', ',', 'Karaj', '.'], dtype=object),
#  array(['Tumba Maydanak', ',', 'siglo XIII', ',', 'Karaj', ';',
#         'Cementerio', 'polaco', 'a', 'el', 'norte', 'de', 'Teherán', ',',
#         'donde', 'están', 'enterrados', 'muchos', 'soldados', 'aliados',
#         'occidentales', ';', 'Iglesias', '.'], dtype=object),
#  array(['Iglesia Surep Georg', ',', '1790', ';',
#         'Iglesia Thaddeus Bartoqimus', ',', '1808', ';', 'Iglesia Tatavus',
#         ',', 'de', 'la', 'era', 'Kayar', ';', 'Iglesia Enjili', ',',
#         '1867', ';', 'Iglesia', 'asiria', ';', 'Colegios', 'y',
#         'universidades', '.'], dtype=object),
#  array(['Principales', 'universidades', 'de', 'la', 'provincia', 'de',
#         'teherán', ':', 'Universidad Allameh Tabatabaii', ';',
#         'Universidad de Tecnología Amirkabir', '(',
#         'Politécnico de Teherán', ')', '(', 'website', ')', ';',
#         'Universidad Alzahra', '(', 'website', ')', ';',
#         'Colegio Técnico Shamsipour', '(', 'website', ')', ';',
#         'Universidad de Ciencias Médicas Baqiyatallah', ';',
#         'Instituto Farabi de Educación Superior Virtual', ';',
#         'Universidad de Irán de Ciencias', 'y', 'Tecnología', '(', 'IUST',
#         ')', '(', 'website', ')', ';', 'Universidad Imam Hossein', ';',
#         'Universidad Imam Sadeq', '(', 'ISU', ')', ';',
#         'Universidad de Irán de Ciencias Médicas', ';',
#         'Universidad de Tecnología K.N. Toosi', ';', 'Universidad Shahed',
#         ';', 'Universidad Shahid Beheshti', '(', 'website', ')', ';',
#         'Universidad de Tecnología Sharif', '(', 'website', ')', ';',
#         'Universidad Tarbiat Modarres', '(', 'Universidad de Formación',
#         'de', 'el', 'profesorado', '(', 'website', ')', ';',
#         'Universidad de Teherán de Ciencias Médicas', ';',
#         'Universidad Tarbiat Moaalem', ';', 'Universidad de Artes', ';',
#         'Universidad de Bienestar Social', 'y',
#         'Ciencias de Rehabilitación', ';', 'Universidad de Teherán', '(',
#         'website', ')', ';',
#         'Universidad Islámica Azad de Teherán-Ciencia', 'e',
#         'Investigación', ';', 'Universidad Islámica Azad de Varamin', ';',
#         'Universidad Islámica Azad de Islamshahr', ';',
#         'Universidad Islámica Azad de Karaj', ';',
#         'Universidad Islámica Azad de Damavand', ';',
#         'Universidad Islámica Azad de Rudehen', ';',
#         'Universidad Islámica Azad de Teherán-Ciencias Médicas', ';',
#         'Universidad Islámica Azad de Teherán-Norte', ';',
#         'Universidad Islámica Azad de Teherán-Sur', ';',
#         'Universidad Islámica Azad de Teherán-Central', ';',
#         'Universidad Islámica Azad de Teherán-Región', '1', ';',
#         'Universidad de Ciencias Médicas Shahid Beheshti', '(', 'website',
#         ')', ';', 'Universidad de Emam Reza', ';',
#         'Instituto para Estudios', 'en', 'Física Teórica', 'y',
#         'Matemáticas', '(', 'IPM', ')', '(', 'website', ')', ';',
#         'Colegio Hadith de Teherán', ';', 'Universidad Imam Ali', 'para',
#         'oficiales', 'de', 'el', 'ejército', ';',
#         'Universidad Integral de Tecnología', ';',
#         'Universidad de Teherán de Ciencias', 'aplicadas', 'y',
#         'tecnología', ';', 'Colegio de Teherán de Medio Ambiente', ';',
#         'Universidad Bagher Aloloum', ';',
#         'Universidad Internacional de Irán', ';',
#         'Colegio de Irán de Telecomunicaciones', ';',
#         'Universidad Médica para el Ejército de la República Islámica de Írán',
#         ';', 'NAJA Universidad de Policía', ';',
#         'Escuela de Asuntos Económicos', '(', 'SEA', ')', ';',
#         'Escuela de Relaciones Internacionales', ';',
#         'Universidad Shahed de Ciencias Médicas', ';',
#         'Universidad Shahid Sattari de Ingeniería Aeronáutica', ';',
#         'Universidad de Sectas Islámicas', ';',
#         'Instituto de Investigación', 'de', 'la', 'industria', 'de', 'el',
#         'petróleo', ';', 'Instituto Petroquímico', 'y', 'de',
#         'Polímeros de Irán', ';', 'Instituto de Tecnología de Energía',
#         'y', 'Agua', '(', 'PWIT', ')', '(', 'website', ')', ';',
#         'Universidad Payame Nur', '(', 'website', ')', ';', 'Véase',
#         'también', '.'], dtype=object),
#  array(['Teherán', '(', 'la', 'ciudad', ')', ';', 'Enlaces', 'externos',
#         '.'], dtype=object),
#  array(['Website', 'oficial', 'de', 'el', 'Gobierno de Teherán', ';',
#         'Organización de el Patrimonio Cultural', 'de', 'la', 'provincia',
#         'de', 'Teherán', ';', 'Iranian Tour Agency Iranian Tours', 'and',
#         'Travel Agencies Travel', 'to', 'Iran', 'website', ';',
#         'ENDOFARTICLE', '.'], dtype=object),
#  array(['Ayatolá Seyyed Ruhollah Musavi Jomeini', '(', 'en', 'persa', ')',
#         '(', '24 de septiembre de 1902', 'y', 'fallecido', 'el',
#         '3 de junio de 1989', ')', '.'], dtype=object),
#  array(['Algunas', 'fuentes', 'declaran', 'que', 'Jomeini', 'nació', 'el',
#         '17 de mayo de 1900', '.'], dtype=object),
#  array(['Fue', 'un', 'imán', 'y', 'ayatolá', 'chií', 'iraní', ',', 'líder',
#         'político-espiritual', 'de', 'la', 'revolución', 'de', '1979', '.'],
#        dtype=object),
#  array(['El', 'mundo', 'occidental', 'lo', 'consideraba', 'un', 'líder',
#         'mesiánico', ',', 'cuyas', 'iniciativas', 'políticas', 'ponían',
#         'en', 'peligro', 'la', 'estabilidad', 'internacional', '.'],
#        dtype=object),
#  array(['En', '1979', 'derrocó', 'a', 'el', 'Sah de Irán', ',',
#         'Mohammad Reza Pahlevi', '.'], dtype=object),
#  array(['Jomeini', 'gobernó', 'Irán', 'hasta', 'que', 'falleció', 'en',
#         '1989', '.'], dtype=object),
#  array(['Es', 'considerado', 'el', 'fundador', 'de', 'el', 'moderno',
#         'estado', 'chií', '.'], dtype=object),
#  array(['Primeras', 'etapas', 'de', 'la', 'vida', '.'], dtype=object),
#  array(['La', 'infancia', ',', 'a el igual que', 'las', 'raíces', 'de',
#         'Jomeini', 'está', 'teñida', 'de', 'tensiones', 'y', 'sinsabores',
#         'que', 'moldearon', 'su', 'carácter', 'y', 'personalidad', 'a',
#         'lo', 'largo', 'de', 'toda', 'su', 'vida', '.'], dtype=object),
#  array(['El', 'abuelo', 'de', 'Jomeini', 'era', 'un', 'hombre', 'con',
#         'propiedades', ',', 'su', 'familia', 'tenía', 'sangre',
#         'profética', 'por', 'parte', 'de', 'la', 'mujer', 'de', 'el',
#         'cuarto', 'califa', ',', 'es', 'decir', 'la', 'hija', 'de', 'el',
#         'profeta', ',', 'Fatima', '.'], dtype=object),
#  array(['La', 'familia', 'de', 'su', 'abuelo', 'que', 'vivía',
#         'a mediados de', 'el', 'S. XVIII', 'a', 'el', 'norte', 'de',
#         'Irán', 'emigrarían', 'desde', 'allí', 'a', 'India', 'para', 'más',
#         'tarde', 'ir', 'a', 'Irak', 'en', 'peregrinación', 'y', 'estudios',
#         ',', 'por', 'último', 'se', 'asentó', 'en', 'Irán', 'en',
#         'Jomeini', ',', 'el', 'centro', 'de', 'Irán', '.'], dtype=object),
#  array(['Por aquel entonces', ',', 'ya', 'había', 'hecho', 'suficiente',
#         'dinero', 'para', 'vivir', 'bien', 'y', 'dar', 'una', 'buena',
#         'educación', 'a', 'su', 'hijo', ',', 'el', 'padre', 'de',
#         'Jomeini', ',', 'el', 'cual', 'recibió', 'educación', 'en', 'las',
#         'escuelas', 'religiosas', ',', 'así', 'este', 'llego', 'a', 'ser',
#         'un', 'clérigo', 'de', 'reconocido', 'prestigio', 'popular',
#         'ya que', 'no sólo', 'vigilaba', 'lo', 'concerniente', 'a', 'la',
#         'práctica', 'de', 'la', 'religión', ',', 'sino', 'también', 'lo',
#         'social', ',', 'judiciales', 'y', 'educacionales', '.'],
#        dtype=object),
#  array(['Fue', 'un', 'hombre', 'muy', 'cercano', 'a', 'los', 'estratos',
#         'sociales', 'más', 'bajos', ',', 'debido a', 'que', 'en', 'su',
#         'época', 'se', 'producían', 'un', 'innumerable', 'número', 'de',
#         'injusticias', 'contra', 'los', 'más', 'desfavorecidos', ',', 'él',
#         'los', 'aportaba', 'protección', 'física', ',', 'legislativa', 'y',
#         'educacional', '.'], dtype=object),
#  array(['Grupos', 'de', 'oficiales', ',', 'sembraban', 'el', 'terror',
#         'entre', 'los', 'campesinos', 'y', 'les', 'hacían', 'pagar',
#         'tasas', 'muy', 'altas', 'con', 'el', 'único', 'objetivo', 'de',
#         'enriquecer', 'sus', 'arcas', ',', 'lo', 'mismo', 'pasaba', 'con',
#         'los', 'príncipes', 'y', 'los', 'Khan', ',', 'esta', 'situación',
#         'obligo', 'a', 'que', 'el', 'padre', 'de', 'Jomeini', 'ha',
#         'armase', 'para', 'defender', 'su', 'familia', 'y', 'a', 'otras',
#         'personas', 'en', 'dificultades', ',', 'pero', 'esta', 'situación',
#         'conlleva', 'un', 'peligro', 'muy', 'grande', 'que', 'pronto',
#         'este', 'pagaría', 'con', 'su', 'vida', '.'], dtype=object),
#  array(['Así pues', ',', 'el', 'aún', 'un', 'bebe', 'futuro', 'ayatolá',
#         'se', 'había', 'quedado', 'sin', 'padre', ',', 'pero', 'sus',
#         'hermanos', 'no', 'dudarían', 'un', 'solo', 'instante', 'en',
#         'hacer', 'pagar', 'la', 'muerte', 'de', 'el', 'asesino', 'de',
#         'su', 'padre', ',', 'estos', 'no', 'se', 'verían', 'solos', 'en',
#         'la', 'búsqueda', 'de', 'la', 'justicia', ',', 'debido a', 'que',
#         'el', 'padre', 'de', 'Jomeini', 'era', 'muy', 'querido', ',',
#         'pero', 'el', 'gobernante', 'Shah', 'no', 'estaba', 'decidido',
#         'de', 'el', 'todo', 'a', 'hacer', 'justicia', ',', 'por', 'lo',
#         'que', 'le', 'llevaría', 'a', 'la', 'familia', 'largo', 'tiempo',
#         'obtener', 'la', ',', 'con', 'esta', 'meta', 'se', 'desplazo', 'a',
#         'la', 'capital', 'Teherán', ',', 'para', 'residir', 'allí', '.'],
#        dtype=object),
#  array(['A', 'la', 'situación', 'interna', 'de', 'el', 'país', 'se',
#         'sumaba', 'las', 'políticas', 'externas', 'de', 'vasallaje', 'que',
#         'tenía', 'Irán', 'con', 'Rusia', 'y', 'Gran Bretaña', 'que',
#         'creaban', 'muchas', 'protestas', 'de', 'la', 'clase',
#         'intelectual', ',', 'clérigos', ',', 'muchos', 'levantamientos',
#         'y', 'muchos', 'de', 'ellos', 'con', 'finales', 'sangrientos', '.'],
#        dtype=object),
#  array(['Nació', 'en', 'la', 'ciudad', 'de', 'Jomein', 'una', 'pequeña',
#         'población', 'ubicada', 'a', '300 km', 'a', 'el', 'sur', 'de',
#         'Teherán', '(', 'capital', 'de', 'Irán', ')', ',', 'como',
#         'Ruhollah Hendi', '.'], dtype=object),
#  array(['A principios de', 'los', 'años', 'treinta', 'tomó', 'el',
#         'nombre', 'de', 'Jomeini', '(', 'en', 'persa', ')', 'en',
#         'directa', 'alusión', 'a', 'su', 'lugar', 'de', 'nacimiento', '.'],
#        dtype=object),
#  array(['Sus', 'padres', 'Jayed Mustafa Mussavi', 'y', 'Hajar Saghafi',
#         ',', 'tuvieron', 'seis', 'hijos', 'de', 'los', 'cuales', 'el',
#         'más', 'joven', 'era', 'Ruhollah Hendi', ',', 'el', 'peso', 'de',
#         'su', 'tradición', 'religiosa', 'de', 'su', 'familia', 'determinó',
#         'desde', 'sus', 'primeros', 'años', 'la', 'vocación', 'de',
#         'Jomeini', '.'], dtype=object),
#  array(['Su', 'abuelo', 'Mirza Ahmad', 'y', 'su', 'hermano', 'Passaiden',
#         'fueron', 'ayatollahs', ',', 'su', 'padre', 'Jayed Mustafa',
#         'también', 'lo', 'fue', ',', 'uniendo', 'a', 'este', 'sus',
#         'convicciones', 'religiosas', 'en', 'un', 'fervor', 'político',
#         'especialmente', 'contra', 'Qataríes', ',', 'la', 'dinastía',
#         'reinante', 'en', 'Irán', 'a principios de', 'el', 'siglo XX', '.'],
#        dtype=object),
#  array(['Jomeini', 'decía', 'ser', 'un', 'sayyid', ',', 'ya que', 'su',
#         'familia', 'afirmaba', 'ser', 'descendiente', 'de', 'Mahoma',
#         'a través de', 'la', 'séptima', 'parte', 'de', 'los', 'Doce',
#         'Imanes', ',', 'Musa', 'al-Kazim', '.'], dtype=object),
#  array(['Varios', 'de', 'sus', 'cercanos', 'antepasados', 'se',
#         'dedicaron', 'a', 'los', 'estudios', 'islámicos', ':', 'su',
#         'padre', 'y', 'sus', 'dos', 'abuelos', 'fueron', 'clérigos',
#         'chiíes', '.'], dtype=object),
#  array(['El', 'abuelo', 'paterno', 'de', 'Jomeini', ',',
#         'Sayid Musawi Ahmad Hindi', ',', 'pasó', 'muchos', 'años', 'en',
#         'la', 'India', ',', 'antes de', 'regresar', 'a', 'Persia', 'para',
#         'comprar', 'una', 'casa', 'en', 'la', 'ciudad', 'de', 'Jomein',
#         ',', 'en', 'la', 'que', 'vivió', 'su', 'familia', 'hasta', 'fines',
#         'de', 'el', 'siglo XX', '.'], dtype=object),
#  array(['Cuando', 'Jomeini', 'tenía', 'cinco', 'meses', 'de', 'edad', ',',
#         'su', 'padre', 'fue', 'asesinado', '.'], dtype=object),
#  array(['Muchos', 'historiadores', 'creen', 'hoy', 'que', 'su', 'padre',
#         'pudo', 'haber', 'sido', 'víctima', 'de', 'una', 'disputa',
#         'local', '.'], dtype=object),
#  array(['Jomeini', 'y', 'la', 'madre', 'de', 'una', 'de', 'sus', 'tías',
#         'procedió', 'a', 'criar', 'lo', 'hasta', '1918', ',', 'cuando',
#         'dos', 'de', 'ellos', 'murieron', '.'], dtype=object),
#  array(['Ruhollah Jomeini', 'comenzó', 'a', 'estudiar', 'el', 'Corán', ',',
#         'libro', 'sagrado', 'de', 'el', 'Islam', ',', 'y', 'para', 'los',
#         'de', 'los', 'persas', 'a', 'los', 'seis', 'años', '.'],
#        dtype=object),
#  array(['a', 'el', 'año', 'siguiente', ',', 'comenzó', 'a', 'asistir', 'a',
#         'una', 'escuela', 'local', ',', 'donde', 'aprendió', 'matemáticas',
#         ',', 'ciencia', ',', 'geografía', ',', 'y', 'otros', 'temas',
#         'tradicionales', '.'], dtype=object),
#  array(['A', 'lo', 'largo', 'de', 'su', 'infancia', ',', 'él', 'continuó',
#         'su', 'educación', 'religiosa', 'y', 'secular', 'con', 'la',
#         'asistencia', 'de', 'sus', 'familiares', ',', 'incluida', 'su',
#         'madre', ',', 'su', 'primo', "Ja'far", ',', 'y', 'su', 'hermano',
#         'mayor', 'Morteza Pasandideh', '.'], dtype=object),
#  array(['A', 'la', 'edad', 'de', 'siete', 'años', ',', 'el', 'joven',
#         'Jomeini', 'perdería', 'a', 'su', 'tía', 'y', 'a', 'su', 'madre',
#         ',', 'quedando', 'así', 'huérfano', ',', 'pero', 'esto', 'no',
#         'fue', 'un', 'freno', 'para', 'este', 'joven', 'que', 'ansiaba',
#         'aprender', 'por', 'encima de', 'todo', 'y', 'poseía', 'una',
#         'vitalidad', 'y', 'fuerza', 'que', 'le', 'hacían', 'destacar',
#         'entre', 'sus', 'amigos', 'de', 'infancia', '.'], dtype=object),
#  array(['Su', 'religión', ',', 'el', 'Islam', 'shi', 'i', 'duodecimano',
#         'sumado', 'a', 'la', 'muerte', 'injusta', 'de', 'su', 'padre', ',',
#         'le', 'harían', 'ver', 'se', 'a', 'si', 'mismo', 'como', 'una',
#         'víctima', 'que', 'debe', 'tomar', 'no sólo', 'una', 'revancha',
#         'contra', 'los', 'que', 'promovieron', 'el', 'asesinato', 'de',
#         'su', 'padre', ',', 'sino', 'también', 'contra', 'todos',
#         'aquellos', 'musulmanes', 'que', 'se', 'desvíen', 'de', 'la',
#         'verdadera', 'práctica', 'de', 'el', 'Islam', '.'], dtype=object),
#  array(['Después de', 'la', 'I Guerra Mundial', ',', 'su', 'familia',
#         'hizo', 'arreglos', 'para', 'que', 'él', 'estudiara', 'en', 'el',
#         'seminario', 'islámico', 'en', 'Isfahán', ',', 'pero', 'en', 'su',
#         'lugar', 'Jomeini', 'se', 'trasladó', 'a', 'Arak', '(', '1920',
#         ')', 'y', 'comenzó', 'sus', 'estudios', ',', 'bajo', 'la',
#         'dirección', 'de', 'el', 'ayatolá', 'Abdul Karim Haeri Yazdi', '.'],
#        dtype=object),
#  array(['a', 'el', 'año', 'siguiente', ',', 'el', 'ayatolá', 'Haeri Yazdi',
#         'transferido', 'el', 'seminario', 'islámico', 'a', 'la', 'ciudad',
#         'santa', 'de', 'Qom', ',', 'a', 'el', 'sudoeste', 'de', 'Teherán',
#         ',', 'e', 'invitó', 'a', 'sus', 'alumnos', 'a', 'seguir', 'le',
#         '.'], dtype=object),
#  array(['Jomeini', 'aceptó', 'la', 'invitación', ',', 'y', 'se',
#         'trasladó', 'a', 'la', 'escuela', 'Dar', 'al-Shafa', ',', 'en',
#         'Qom', '.'], dtype=object),
#  array(['Entre', 'los', 'estudios', 'de', 'Jomeini', 'se', 'incluyeron',
#         'la', 'Sharia', '(', 'ley', 'islámica', ')', 'y', 'el', 'Fiqh',
#         '(', 'jurisprudencia', ')', '.'], dtype=object),
#  array(['Jomeini', 'también', 'había', 'adquirido', 'un', 'interés', 'en',
#         'la', 'poesía', 'y', 'la', 'filosofía', 'Irfan', '.'], dtype=object),
#  array(['Así', 'que', 'a', 'el', 'llegar', 'a', 'Qom', ',', 'Jomeini',
#         'trató', 'la', 'orientación', 'de', 'Mirza Ali Akbar Yazdi', ',',
#         'un', 'estudioso', 'de', 'la', 'filosofía', 'y', 'la', 'mística',
#         '.'], dtype=object),
#  array(['Yazdi', 'murió', 'en', '1924', ',', 'pero', 'Jomeini', 'seguió',
#         'con', 'su', 'interés', 'en', 'la', 'filosofía', 'con', 'otros',
#         'dos', 'profesores', ',', 'Javad Aqa Maleki Tabrizi', 'y',
#         "Rafi'i Qazvini", '.'], dtype=object),
#  array(['Sin', 'embargo', ',', 'tal vez', 'la', 'mayor', 'la', 'mayor',
#         'influencia', 'de', 'Jomeini', 'fue', 'otro', 'maestro', ',',
#         'Mirza Muhammad Ali Shahabadi', ',', 'y', 'una', 'gran',
#         'variedad', 'de', 'históricos', 'místicos', 'sufíes', ',',
#         'incluyendo', 'Mulla Sadra', 'y', 'Ibn Arabi', '.'], dtype=object),
#  array(['Profesor', 'y', 'estudioso', '.'], dtype=object),
#  array(['Literatura', 'y', 'poesía', '.'], dtype=object),
#  array(['Aparte de', 'la', 'filosofía', ',', 'Jomeini', 'también',
#         'estaba', 'interesado', 'en', 'la', 'literatura', 'y', 'la',
#         'poesía', '.'], dtype=object),
#  array(['Su', 'colección', 'de', 'poesía', 'se', 'publicó', 'después de',
#         'su', 'muerte', '.'], dtype=object),
#  array(['Desde', 'su', 'adolescencia', ',', 'Jomeini', 'escribía',
#         'poesía', 'mística', ',', 'política', 'y', 'social', '.'],
#        dtype=object),
#  array(['Nosotros', 'y', 'yo', 'son', 'a la vez', 'de', 'la', 'razón', ';',
#         'Que', 'se', 'utilizan', 'como', 'cuerdas', 'de', 'obligar', 'a',
#         'En', 'la', 'masa', 'de', 'los', 'que', 'se', 'beben', 'Ni', 'yo',
#         'es', 'ni', '"', 'nosotros', '"', 'para', 'encontrar', '"', '|',
#         'Ruhollah Jomeini', '}', '}', 'Su', 'poesía', 'obras', 'se',
#         'publicaron', 'en', 'tres', 'colecciones', 'El Confidente', ',',
#         'El Decante de Amor', 'y', 'Diván', '.'], dtype=object),
#  array(['Política', '.'], dtype=object),
#  array(['Jomeini', 'fue', 'nombrado', 'ayatolá', 'en', 'los', 'años',
#         '1950', '.'], dtype=object),
#  array(['En', '1964', 'se', 'exilió', 'por', 'sus', 'críticas', 'a', 'el',
#         'gobierno', 'de', 'el', 'sah', 'Mohammad Reza Pahlavi', '.'],
#        dtype=object),
#  array(['Estuvo', 'en', 'Iraq', 'hasta', 'que', 'se', 'vio', 'obligado',
#         'a', 'abandonar', 'el', 'país', 'en', '1978', ',', 'estableciendo',
#         'se', 'en', 'Neaufle-le-Château', 'en', 'Francia', '.'],
#        dtype=object),
#  array(['Aspectos', 'políticos', '.'], dtype=object),
#  array(['Jomeini', 'volvió', 'a', 'Irán', 'el', '11 de febrero de 1979',
#         ',', 'cuando', 'la', 'revolución', 'ya', 'se', 'había',
#         'consumado', ',', 'estableciendo', 'la', 'República Islámica',
#         'con', 'un', 'presidente', 'electo', 'cada', 'cuatro', 'años', ',',
#         'reservando', 'se', 'Jomeini', 'la', 'jefatura', 'de', 'estado',
#         'con', 'la', 'denominación', 'de', 'Líder Supremo de Irán', '.'],
#        dtype=object),
#  array(['El', 'gobierno', 'de', 'Jomeini', 'interrumpió', 'la',
#         'occidentalización', 'llevada a cabo', 'por', 'el', 'sah', '.'],
#        dtype=object),
#  array(['La', 'ley', 'islámica', 'fue', 'instaurada', '.'], dtype=object),
#  array(['En', 'noviembre de 1979', 'algunos', 'seguidores', 'de',
#         'Jomeini', 'asaltaron', 'la', 'embajada', 'de', 'Estados Unidos',
#         'en', 'Teherán', 'como', 'protesta', 'ante', 'el',
#         'intervencionismo', 'estadounidense', '.'], dtype=object),
#  array(['La', 'permisividad', 'de', 'Jomeini', 'ante', 'estos', 'hechos',
#         'provocó', 'la', 'denominada', 'crisis', 'de', 'los', 'rehenes',
#         ',', 'que', 'duraría', '444', 'días', '.'], dtype=object),
#  array(['La', 'nueva', 'Constitución de la República Islámica de Irán',
#         ',', 'aprobada', 'en', 'diciembre de 1979', ',', 'le', 'convirtió',
#         'en', 'el', 'supremo', 'líder', 'político', 'y', 'religioso', 'de',
#         'forma', 'vitalicia', '.'], dtype=object),
#  array(['Su', 'régimen', 'apoyó', 'activamente', 'la', 'actuación', 'de',
#         'grupos', 'terroristas', 'y', 'la', 'propagación', 'de', 'las',
#         'creencias', 'radicales', 'fundamentalistas', 'islámicas', '.'],
#        dtype=object),
#  array(['El', '4 de febrero de 1980', 'Jomeini', 'aceptó', 'la',
#         'elección', 'de', 'Abolhassan Banisadr', 'como', 'primer',
#         'presidente', 'de', 'Irán', '.'], dtype=object),
#  array(['Con', 'el', 'pretexto', 'de', 'una', 'disputa', 'territorial',
#         'fronteriza', 'entre', 'Iraq', 'e', 'Irán', ',', 'en', '1980',
#         'Saddam Hussein', 'inició', 'una', 'guerra', 'que', 'duraría', '8',
#         'años', ',', 'la', 'Guerra Irán-Iraq', '.'], dtype=object),
#  array(['Jomeini', 'acordaría', 'contra', 'su', 'voluntad', 'el', 'alto',
#         'a', 'el', 'fuego', 'final', 'el', '20 de agosto de 1988', '.'],
#        dtype=object),
#  array(['A pesar de', 'el', 'coste', 'económico', 'y', 'humano', 'de',
#         'su', 'gobierno', ',', 'Jomeini', 'disfrutó', 'de', 'un',
#         'considerable', 'apoyo', 'popular', 'dentro de', 'Irán', ',',
#         'aunque', 'aparecieron', 'signos', 'de', 'que', 'su', 'política',
#         'más', 'extrema', 'no', 'sobreviviría', 'a', 'su', 'muerte', 'que',
#         'se', 'convirtió', 'en', 'un', 'auténtico', 'duelo', 'nacional',
#         'y', ',', 'en', 'la', 'actualidad', ',', 'su', 'tumba', 'es',
#         'centro', 'de', 'peregrinaciones', 'y', 'de', 'culto',
#         'multitudinario', '.'], dtype=object),
#  array(['Referencias', '.'], dtype=object),
#  array(['Enlaces', 'externos', '.'], dtype=object),
#  array(['La', 'doctrina', 'política', 'de', 'Jomeini En', 'revista',
#         'Alif Nûn', 'nº', '46', ',', 'febrero de 2007', '.'], dtype=object),
#  array(['ENDOFARTICLE', '.'], dtype=object),
#  array(['Qom', '(', 'en', 'persa', ':', ')', 'es', 'una', 'de', 'las',
#         '30', 'provincias', 'de', 'Irán', '.'], dtype=object),
#  array(['Se', 'ubica', 'a', 'el', 'norte', 'de', 'el', 'país', ',', 'y',
#         'su', 'capital', 'es', 'la', 'ciudad', 'de', 'Qom', '.'],
#        dtype=object),
#  array(['Se', 'formó', 'en', '1995', ',', 'separando', 'se', 'de', 'la',
#         'provincia', 'de', 'Teherán', '.'], dtype=object),
#  array(['En', '2005', ',', 'esta', 'provincia', 'tenía', 'una',
#         'población', 'de', 'aproximadamente', 'dos millones', 'de',
#         'personas', ',', 'de', 'las', 'cuales', 'el', '91,2 %', 'residían',
#         'en', 'zonas', 'urbanas', 'y', 'el', '8,8 %', 'en', 'vecindarios',
#         'rurales', '.'], dtype=object),
#  array(['La', 'provincia', 'incluye', 'una', 'ciudad', ',', 'cuatro',
#         'municipios', ',', 'nueve', 'distritos', 'rurales', ',', 'y',
#         '256', 'pueblos', '.'], dtype=object),
#  array(['Geografía', '.'], dtype=object),
#  array(['Abarca', 'una', 'superficie', 'de', '11.237', 'km²', ',', 'lo',
#         'que', 'supone', 'el', '0,89 %', 'de', 'la', 'superficie', 'total',
#         'de', 'Irán', '.'], dtype=object),
#  array(['El', 'clima', 'de', 'la', 'provincia', 'de', 'Qom', 'varía',
#         'entre', 'el', 'desértico', 'y', 'el', 'semidesértico', ',', 'y',
#         'comprende', 'áreas', 'con', 'montañas', ',', 'colinas', 'y',
#         'planicies', '.'], dtype=object),
#  array(['Debido a', 'que', 'se', 'localiza', 'lejos de', 'el', 'mar', 'y',
#         'cerca', 'de', 'una', 'región', 'árida', ',', 'presenta', 'un',
#         'clima', 'seco', ',', 'con', 'escasa', 'precipitación', 'y',
#         'baja', 'humedad', '.'], dtype=object),
#  array(['Por', 'tanto', ',', 'la', 'agricultura', 'no', 'es', 'posible',
#         'en', 'la', 'mayor', 'parte', 'de', 'el', 'territorio', ',',
#         'especialmente', 'cerca', 'de', 'las', 'regiones', 'lacustres',
#         'salinas', '.'], dtype=object),
#  array(['La', 'provincia', 'tiene', 'dos', 'grandes', 'lagos', 'salados',
#         ',', 'el', 'lago', 'Howz', 'e', 'Soltan', ',', 'que', 'queda',
#         '36 kilómetros', 'a', 'el', 'norte', 'de', 'Qom', ',', 'y', 'el',
#         'Lago Namak', ',', 'que', 'queda', '80 kilómetros', 'a', 'el',
#         'este', 'de', 'Qom', '.'], dtype=object),
#  array(['Casi', 'un quinto', 'de', 'el', 'lago', 'Namak', 'se',
#         'encuentra', 'dentro de', 'la', 'provincia', 'de', 'Qom', '.'],
#        dtype=object),
#  array(['Divisiones', 'administrativas', '.'], dtype=object),
#  array(['De', 'manera', 'única', 'en', 'Irán', ',', 'la', 'provincia',
#         'de', 'Qom', 'es', 'con', 'el', 'Shahrestan de Qom', '.'],
#        dtype=object),
#  array(['Historia', '.'], dtype=object),
#  array(['Se', 'cree', 'que', 'Qom', 'ha', 'existido', 'en', 'época',
#         'preislámica', '.'], dtype=object),
#  array(['Descubrimientos', 'arqueológicos', 'indican', 'que', 'Qom', 'era',
#         'una', 'zona', 'residencial', 'desde', 'el', 'V', 'milenio', 'a',
#         '.'], dtype=object),
#  array(['C. Según', 'los', 'restos', 'que', 'quedan', 'preislámicos', 'y',
#         'los', 'textos', 'históricos', ',', 'Qom', 'era', 'una', 'gran',
#         'ciudad', '.', '"', 'Kom', '"', 'era', 'el', 'nombre', 'de', 'la',
#         'antigua', 'muralla', 'de', 'la', 'ciudad', 'de', 'Qom', ',', 'de',
#         'ahí', 'que', 'los', 'árabes', 'la', 'llamaran', 'Qom', 'durante',
#         'la', 'conquista', 'árabe', 'de', 'Irán', '.'], dtype=object),
#  array(['Fue', 'durante', 'el', 'reinado', 'de', 'el', 'segundo', 'califa',
#         ',', 'Omar', 'que', 'los', 'musulmanes', 'tomaron', 'el', 'centro',
#         'de', 'Qom', '.'], dtype=object),
#  array(['En', '644-645', ',', 'Abu Musa Ashari', 'envió', 'fuerzas', 'a',
#         'su', 'mando', 'a', 'Qom', '.'], dtype=object),
#  array(['Los', 'conflictos', 'surgieron', 'entre', 'los', 'árabes',
#         'invasores', 'y', 'los', 'residentes', 'de', 'la', 'zona', '.'],
#        dtype=object),
#  array(['Durante', 'la', 'persecución', 'de', 'los', 'alávidas', 'los',
#         'abasíes', 'y', 'los', 'omeyas', ',', 'muchos', 'alávidas',
#         'huyeron', 'a', 'Qom', ',', 'haciendo', 'de', 'ella', 'su',
#         'residencia', 'permanente', '.'], dtype=object),
#  array(['El', 'califa', "Al-Ma'mun", 'envió', 'fuerzas', 'a', 'Qom', 'en',
#         'el', 'año 825', ',', 'y', 'dio', 'como', 'resultado', 'una',
#         'matanza', 'pública', 'y', 'la', 'destrucción', 'de', 'la',
#         'ciudad', '.'], dtype=object),
#  array(['a', 'el', 'oír', 'el', 'fallecimiento', 'de', "Al-Ma'mun", ',',
#         'los', 'habitantes', 'de', 'Qom', 'se', 'rebelaron', 'y',
#         'tuvieron', 'éxito', 'derrotando', 'a', 'los', 'representantes',
#         'de', 'el', 'calife', 'en', '831', '.'], dtype=object),
#  array(['Sin', 'embargo', ',', 'el', 'sucesor', 'de', "Al-Ma'mun", ',',
#         "al-Mu'tasim", ',', 'envió', 'fuerzas', 'a', 'Qom', 'para',
#         'refrenar', 'los', 'disturbios', 'y', 'de', 'nuevo', 'la',
#         'ciudad', 'quedó', 'sometida', '.'], dtype=object),
#  array(['La', 'inquietud', 'continuó', 'hasta', 'la', 'dinastía', 'búyida',
#         '(', 'a', 'el', 'e', 'Buyeh', 'en', 'persa', ')', 'por', 'ser',
#         'de', 'la', 'comunidad', 'alávida', '.'], dtype=object),
#  array(['Fue', 'durante', 'este', 'reinado', 'que', 'la', 'ciudad', 'de',
#         'Qom', 'se', 'expandió', 'y', 'prosperó', '.'], dtype=object),
#  array(['En', 'la', 'época', 'selyúcida', 'la', 'ciudad', 'volvió', 'a',
#         'florecer', '.'], dtype=object),
#  array(['Durante', 'la', 'primera', 'ola', 'de', 'la', 'invasión',
#         'mongola', ',', 'la', 'ciudad', 'fue', 'testigo', 'de',
#         'destrucción', ',', 'pero', 'después', 'los', 'gobernantes',
#         'mongoles', ',', 'particularmente', 'después de', 'que', 'el',
#         'sultán', 'Öljeitü', 'Joda', 'bandeh', 'de', 'la', 'dinastía',
#         'Iljánida', 'se', 'convirtiese', 'a', 'el', 'Islam', ',', 'la',
#         'ciudad', 'recibió', 'especial', 'atención', ',', 'viendo', 'así',
#         'un', 'nuevo', 'renacimiento', '.'], dtype=object),
#  array(['A', 'finales', 'de', 'el', 'siglo XIV', ',', 'la', 'ciudad',
#         'fue', 'saqueada', 'por', 'Tamerlán', 'cuando', 'los',
#         'habitantes', 'fueron', 'de', 'nuevo', 'masacrados', '.'],
#        dtype=object),
#  array(['Durante', 'los', 'periódos', 'de', 'gobierno', 'de', 'los',
#         'Kara Koyunlu', ',', 'Ak Koyunlu', 'y', 'especialmente', 'durante',
#         'el', 'reinado', 'de', 'los', 'safávidas', ',', 'Qom', 'mereció',
#         'especial', 'atención', 'y', 'gradualmente', 'fue',
#         'desarrollando', 'se', '.'], dtype=object),
#  array(['Para', '1503', ',', 'Qom', 'era', 'uno', 'de', 'los',
#         'importantes', 'centros', 'de', 'teología', 'en', 'relación',
#         'con', 'el', 'Islam', 'chiíta', 'y', 'se', 'convirtió', 'en', 'un',
#         'centro', 'de', 'peregrinación', 'vital', 'y', 'pivote',
#         'religioso', '.'], dtype=object),
#  array(['Durante', 'la', 'invasión', 'afgana', ',', 'la', 'ciudad', 'de',
#         'Qom', 'sufrió', 'grandes', 'daños', ',', 'y', 'sus', 'habitantes',
#         'sufrieron', 'contrariedades', 'económicas', 'duras', '.'],
#        dtype=object),
#  array(['Qom', 'padeció', 'nuevamente', 'daños', 'durante', 'los',
#         'reinados', 'de', 'Nadir Sah', 'y', 'los', 'conflictos', 'entre',
#         'las', 'dos', 'dinastías', 'de', 'Zand', 'y', 'Kayar', 'por', 'el',
#         'poder', 'en', 'Irán', '.'], dtype=object),
#  array(['En', '1798', ',', 'Qom', 'fue', 'controlada', 'por',
#         'Aga Muhammad Kan', '.'], dtype=object),
#  array(['a', 'el', 'vencer', 'a', 'sus', 'enemigos', ',', 'Fath Alí Sah',
#         'hizo', 'reparaciones', 'a', 'el', 'sepulcro', 'y',
#         "Sagrado Santuario de Hazrat Ma'sumeh", ',', 'cumpliendo', 'su',
#         'voto', '.'], dtype=object),
#  array(['La', 'ciudad', 'de', 'Qom', 'prosperó', 'en', 'la', 'época',
#         'Kayar', '.'], dtype=object),
#  array(['Después', 'fuerzas', 'rusas', 'entraron', 'en', 'Karaj', 'en',
#         '1915', ',', 'muchos', 'habitantes', 'de', 'Teherán', 'se',
#         'trasladaron', 'a', 'Qom', '.'], dtype=object),
#  array(['La', 'transferencia', 'de', 'la', 'capitalidad', 'de', 'Teherán',
#         'a', 'Qom', 'fue', 'discutida', ',', 'pero', 'los', 'británicos',
#         'y', 'los', 'rusos', 'acabaron', 'con', 'el', 'plan', 'sometiendo',
#         'a', 'presión', 'a', 'el', 'monarca', 'de', 'la', 'época', ',',
#         'Ajmad Sah Kayar', '.'], dtype=object),
#  array(['Coincidiendo', 'con', 'este', 'período', ',', 'se', 'estableció',
#         'un', 'Comité', 'de', 'defensa', 'Nacional', ',', 'y', 'Qom',
#         'fue', 'un', 'centro', 'militar', 'y', 'político', 'contra', 'las',
#         'potencias', 'coloniales', 'británica', 'y', 'rusa', '.'],
#        dtype=object),
#  array(['Qom', 'fue', 'también', 'el', 'centro', 'desde', 'el', 'cual',
#         'el', 'ayatolá', 'Jomeini', 'fundó', 'su', 'oposición', 'a', 'la',
#         'dinastía', 'Pahlavi', ',', 'mientras', 'estuvo', 'en', 'Irán',
#         '.'], dtype=object),
#  array(['Qom', 'hoy', '.'], dtype=object),
#  array(['Hoy', ',', 'Qom', 'está', 'considerado', 'como', 'uno', 'de',
#         'los', 'centros', 'focales', 'de', 'la', 'secta', 'chiíta',
#         'tanto', 'en', 'Irán', 'como', 'en', 'el', 'resto', 'de', 'el',
#         'mundo', '.'], dtype=object),
#  array(['Su', 'centro', 'teológico', 'y', 'el',
#         "Santuario Sagrado de Hazrat Ma'sumeh", 'son', 'rasgos',
#         'destacados', 'de', 'la', 'capital', 'provincial', 'de', 'la',
#         'provincia', 'de', 'Qom', '.'], dtype=object),
#  array(['Otro', 'lugar', 'religioso', 'de', 'peregrinación', 'está',
#         'afuera', 'de', 'la', 'ciudad', 'de', 'Qom', ',', 'y', 'se',
#         'llama', 'Jamkaran', '.'], dtype=object),
#  array(['La', 'proximidad', 'de', 'Qom', 'a', 'Teherán', 'le', 'ha',
#         'supuesto', 'igualmente', 'una', 'ventaja', '.'], dtype=object),
#  array(['Qom', 'a', 'veces', 'ha', 'sido', 'considerada', 'como', 'un',
#         'posible', 'candidato', 'para', 'el', 'traslado', 'de', 'la',
#         'capital', 'política', 'de', 'Irán', ',', 'pues', 'Teherán', 'se',
#         'enfrenta', 'a', 'una', 'creciente', 'probabilidad', 'de', 'un',
#         'gran', 'terremoto', 'largamente', 'esperado', ',', 'además de',
#         'su', 'tristemente', 'famosa', 'polución', 'y', 'congestión', 'de',
#         'tráfico', '.'], dtype=object),
#  array(['Las', 'facciones', 'conservadoras', 'son', 'favorables', 'a',
#         'esta', 'idea', ',', 'mientras que', 'la', 'base', 'económiga',
#         'y', 'de', 'negocios', 'de', 'Teherán', 'se', 'opone', 'a',
#         'semejante', 'cambio', '.'], dtype=object),
#  array(['Cultura', '.'], dtype=object),
#  array(['La', 'Organización de el Patrimonio Cultural', 'de', 'irán',
#         'incluye', '195', 'lugares', 'de', 'interés', 'histórico', 'y',
#         'cultural', 'en', 'Qom', '.'], dtype=object),
#  array(['Los', 'lugares', 'más', 'visitados', 'son', ':', 'Cueva de Kahak',
#         ';', 'Cueva de Vashnuh', ';', 'Lago', 'salado', 'de', 'Howz', 'e',
#         'Soltan', ';', 'Gran', 'lago', 'salado', 'de', 'Namak', ';',
#         "Biblioteca Mar'ashi Najafi", ',', 'con', 'más', 'de',
#         'medio millón', 'de', 'textos', 'manuscritos', 'y', 'copias', ';',
#         'Museo Astaneh Moqaddaseh', ';', 'Bazar de Qom', ';',
#         'Seminario Feyzieh', ';', 'Mezquita Jamkaran', ';',
#         'Mezquita Qom Jame', "'", ';', 'Mezquita Qom Atiq', ';',
#         "Mezquita A'zam", ';', 'Santuario de Hazrat Masumeh', ';',
#         'Colegios', 'y', 'Universidades', '.'], dtype=object),
#  array(['Universidad de Qom', ';', 'Universidad Islámica Azad de Qom', ';',
#         'El Instituto de Investigación de Hawzeh', 'va', 'Daneshgah', ';',
#         'Centro', 'de', 'investigación', 'computacional', 'de',
#         'Ciencias Islámicas', ',', 'Qom', ';',
#         'Instituto de Investigación', 'y', 'Educación Imán Jomeini', ';',
#         'Universidad de Ciencias Médicas de Qom', ';',
#         'Seminario Feyzieh de Qom', '(', 'llamado', 'El Hawzah', ')', ';',
#         'Universidad Payam Nur de Qom', ';', 'Universidad Mofid', ';',
#         'Enlaces', 'externos', '.'], dtype=object),
#  array(['Excavaciones', 'arqueológicas', 'frustradas', 'en', 'Qom', ';',
#         'Biblioteca Nur Fiqh', ',', 'Qom', ';', 'Instituto Dar-ul Hadith',
#         ';', 'Páginas', 'amarillas', 'Hawzah', ';',
#         'Organización de el Patrimonio Cultural de Qom', ';', 'Website',
#         'de', 'el', 'gobernador', 'de', 'Qom', ';', 'Organización', 'de',
#         'terminales', 'y', 'transporte', 'de', 'la', 'provincia', 'de',
#         'Qom', ';', 'Compañía de Telecomunicaciones de Qom', ';',
#         'Qom News Website', ';', 'ENDOFARTICLE', '.'], dtype=object),
#  array(['La', 'fenilcetonuria', ',', 'es', 'un', 'tipo', 'de',
#         'Hiperfenilalaninemia', ',', 'también', 'conocida', 'como', 'PKU',
#         ',', 'es', 'una', 'alteración', 'de', 'el', 'metabolismo', 'en',
#         'el', 'que', 'el', 'organismo', 'no', 'puede', 'metabolizar', 'el',
#         'aminoácido', 'fenilalanina', 'en', 'el', 'higado', '.'],
#        dtype=object),
#  array(['Esta', 'enfermedad', 'es', 'genética', 'y', 'es', 'provocada',
#         'por', 'la', 'carencia', 'de', 'enzima', 'fenilalanina',
#         'hidroxilasa', '.'], dtype=object),
#  array(['Antecedentes', 'históricos', '.'], dtype=object),
# ...
#  array(['Lisis', 'había', 'ido', 'a', 'vivir', 'con', 'Polymnis', 'en',
#         'la', 'época', 'de', 'su', 'exilio', ',', 'lo', 'cual', 'permitió',
#         'a', 'Epaminondas', 'trabajar', 'mucho', 'con', 'él', ',', 'por',
#         'lo', 'que', 'terminó', 'destacando', 'en', 'sus', 'excelentes',
#         'estudios', 'filosóficos', '.'], dtype=object),
#  array(['Sin', 'embargo', ',', 'Epaminondas', 'no', 'era', 'sólo', 'un',
#         'académico', '.'], dtype=object),
#  array(['También', 'resaltó', 'por', 'sus', 'cualidades', 'físicas', 'y',
#         'durante', 'su', 'juventud', 'dedicó', 'mucho', 'tiempo', 'a',
#         'la', 'preparación', 'física', 'de cara a', 'el', 'combate', '.'],
#        dtype=object),
#  array(['En', '385', 'a', '.'], dtype=object),
#  array(['C.', ',', 'en', 'una', 'escaramuza', 'cerca', 'de', 'la',
#         'ciudad', 'de', 'Mantinea', ',', 'Epaminondas', 'salvó', 'la',
#         'vida', 'de', 'su', 'futuro', 'colega', 'Pelópidas', 'poniendo',
#         'en', 'grave', 'riesgo', 'la', 'suya', 'propia', '.'], dtype=object),
#  array(['Este', 'acto', 'pudo', 'cimentar', 'lo', 'que', 'luego', 'fue',
#         'una', 'amistad', 'entre', 'los', 'dos', 'que', 'duró', 'toda',
#         'la', 'vida', '.'], dtype=object),
#  array(['A través de', 'toda', 'su', 'carrera', ',', 'Epaminondas',
#         'seguiría', 'siendo', 'destacado', 'por', 'su', 'capacidad',
#         'táctica', 'y', 'su', 'manejo', 'de', 'el', 'combate', 'cuerpo',
#         'a', 'cuerpo', '.'], dtype=object),
#  array(['Epaminondas', 'no', 'se', 'casó', 'nunca', ',', 'lo', 'cual',
#         'le', 'supuso', 'muchas', 'críticas', 'por', 'parte', 'de', 'sus',
#         'contemporáneos', ',', 'que', 'pensaban', 'que', 'un', 'personaje',
#         'como', 'él', 'estaba', 'obligado', 'a', 'proveer', 'a', 'su',
#         'estado', 'con', 'el', 'beneficio', 'de', 'hijos', 'que', 'fueran',
#         'tan', 'grandes', 'como', 'lo', 'había', 'sido', 'su', 'padre',
#         '.'], dtype=object),
#  array(['En', 'respuesta', 'Epaminondas', 'dijo', 'que', 'su', 'victoria',
#         'en', 'Leuctra', 'era', 'una', 'hija', 'destinada', 'a', 'vivir',
#         'por', 'siempre', '.'], dtype=object),
#  array(['Se', 'sabe', ',', 'sin', 'embargo', ',', 'que', 'tuvo',
#         'diversas', 'relaciones', 'amorosas', 'con', 'jóvenes', 'griegos',
#         ',', 'una', 'costumbre', 'que', 'era', 'habitual', 'en', 'la',
#         'antigua', 'Grecia', ',', 'y', 'que', 'lo', 'era', 'muy',
#         'particularmente', 'en', 'Tebas', '.'], dtype=object),
#  array(['Plutarco', 'recoge', 'que', 'los', 'legisladores', 'tebanos',
#         'instituyeron', 'la', 'práctica', 'para', '«', 'atemperar', 'las',
#         'formas', 'y', 'el', 'carácter', 'de', 'los', 'jóvenes', '»', '.'],
#        dtype=object),
#  array(['Una', 'anécdota', 'contada', 'por', 'Cornelio Nepote', 'indica',
#         'que', 'Epaminondas', 'había', 'intimado', 'con', 'un', 'joven',
#         'llamado', 'Micitos', '.'], dtype=object),
#  array(['Plutarco', 'también', 'menciona', 'a', 'dos', 'de', 'sus',
#         'amantes', ':', 'Asópico', ',', 'que', 'luchó', 'con', 'él', 'en',
#         'la', 'Batalla de Leuctra', ',', 'en', 'la', 'que', 'se',
#         'distinguió', 'enormemente', ';', 'y', 'Capisdoros', ',', 'que',
#         'murió', 'con', 'Epaminondas', 'en', 'Mantinea', 'y', 'fue',
#         'enterrado', 'a', 'su', 'lado', '.'], dtype=object),
#  array(['Epaminondas', 'vivió', 'toda', 'su', 'vida', 'en', 'una',
#         'situación', 'cercana', 'a', 'la', 'pobreza', ',', 'debido a',
#         'su', 'rechazo', 'de', 'el', 'enriquecimiento', 'personal',
#         'a través de', 'su', 'poder', 'político', '.'], dtype=object),
#  array(['Cornelio Nepote', 'deja', 'constancia', 'de', 'su',
#         'incorruptibilidad', ',', 'describiendo', 'cómo', 'rechazó', 'a',
#         'un', 'embajador', 'persa', 'que', 'llegó', 'a', 'él', 'con', 'un',
#         'soborno', '.'], dtype=object),
#  array(['Siguiendo', 'la', 'costumbre', 'de', 'los', 'pitagóricos', ',',
#         'era', 'dadivoso', 'con', 'sus', 'amigos', 'y', 'les',
#         'recomendaba', 'a', 'que', 'hiciesen', 'lo', 'mismo', 'con', 'los',
#         'demás', '.'], dtype=object),
#  array(['Todos', 'estos', 'aspectos', 'de', 'su', 'carácter',
#         'contribuyeron', 'de', 'forma', 'muy', 'importante', 'a', 'el',
#         'renombre', 'que', 'adquirió', 'tras', 'su', 'muerte', '.'],
#        dtype=object),
#  array(['Comienzos', 'de', 'su', 'carrera', '.'], dtype=object),
#  array(['Epaminondas', 'vivió', 'una', 'época', 'particularmente',
#         'turbulenta', 'en', 'la', 'historia', 'tebana', '.'], dtype=object),
#  array(['Después de', 'la', 'Guerra de el Peloponeso', ',', 'en', '404',
#         'a', '.'], dtype=object),
#  array(['C.', ',', 'Esparta', 'se', 'embarcó', 'en', 'una', 'política',
#         'unilateral', 'e', 'individualista', 'muy', 'agresiva', 'contra',
#         'el', 'resto', 'de', 'polis', 'griegas', ',', 'y', 'rápidamente',
#         'fue', 'alienando', 'a', 'muchos', 'de', 'sus', 'antiguos',
#         'aliados', '.'], dtype=object),
#  array(['Tebas', ',', 'mientras', 'tanto', ',', 'había', 'incrementado',
#         'mucho', 'su', 'poder', 'durante', 'la', 'guerra', ',', 'y',
#         'buscaba', 'ganar', 'el', 'control', 'sobre', 'otras', 'ciudades',
#         'de', 'Beocia', '(', 'la', 'región', 'de', 'la', 'antigua',
#         'Grecia', 'a', 'el', 'noroeste', 'de', 'Ática', ')', '.'],
#        dtype=object),
#  array(['Esta', 'política', ',', 'así como', 'algunas', 'otras',
#         'disputas', 'más', ',', 'llevaron', 'a', 'Tebas', 'a', 'un',
#         'conflicto', 'con', 'Esparta', '(', 'un', 'antiguo', 'aliado', ')',
#         'en', 'la', 'Guerra de Corinto', '.'], dtype=object),
#  array(['En', 'esa', 'guerra', ',', 'que', 'se', 'prolongó', 'durante',
#         'ocho', 'años', 'y', 'acabó', 'sin', 'decantar', 'se',
#         'definitivamente', 'por', 'ninguno', 'de', 'los', 'dos', 'bandos',
#         ',', 'se', 'produjeron', 'algunas', 'derrotas', 'tebanas', 'muy',
#         'sangrientas', 'en', 'enfrentamientos', 'contra', 'Esparta', '.'],
#        dtype=object),
#  array(['Para', 'cuando', 'acabó', 'la', 'guerra', 'Tebas', 'se', 'vio',
#         'forzada', 'a', 'olvidar', 'sus', 'ambiciones', 'expansionistas',
#         'y', 'volver', 'a', 'su', 'antigua', 'alianza', 'con', 'Esparta',
#         '.'], dtype=object),
#  array(['En', '382', 'a', '.'], dtype=object),
#  array(['C.', ',', 'sin', 'embargo', ',', 'el', 'comandante', 'espartano',
#         'Febidas', 'cometió', 'un', 'error', 'estratégico', 'que', 'hizo',
#         'que', 'Tebas', 'se', 'volviese', 'en contra de', 'Esparta',
#         'definitivamente', ',', 'y', 'que', 'pavimentó', 'el', 'camino',
#         'para', 'la', 'llegada', 'a', 'el', 'poder', 'de', 'Epaminondas',
#         '.'], dtype=object),
#  array(['Atravesando', 'Beocia', 'para', 'una', 'campaña', ',', 'Febidas',
#         'se', 'aprovechó', 'de', 'una', 'revuelta', 'civil', 'en', 'Tebas',
#         'para', 'asegurar', 'la', 'entrada', 'a', 'la', 'ciudad', 'a',
#         'sus', 'tropas', '.'], dtype=object),
#  array(['Una', 'vez', 'dentro', ',', 'asedió', 'Cadmea', '(', 'la',
#         'acrópolis', 'tebana', ')', ',', 'y', 'forzó', 'a', 'el',
#         'partido', 'anti-espartano', 'a', 'huir', 'de', 'la', 'ciudad',
#         '.'], dtype=object),
#  array(['Epaminondas', ',', 'si', 'bien', 'estaba', 'asociado', 'a', 'esa',
#         'facción', ',', 'pudo', 'quedar', 'se', 'en', 'la', 'ciudad',
#         'porque', 'se', 'pensaba', 'que', 'no', 'era', 'más', 'que', 'un',
#         'filósofo', 'empobrecido', 'y', 'completamente', 'inofensivo', '.'],
#        dtype=object),
#  array(['Golpe', 'de', 'estado', 'en', 'Tebas', '.'], dtype=object),
#  array(['En', 'los', 'años', 'posteriores', 'a', 'la', 'toma', 'de',
#         'control', 'de', 'Esparta', ',', 'los', 'tebanos', 'exiliados',
#         'por', 'el', 'nuevo', 'gobierno', 'se', 'reagruparon', 'en',
#         'Atenas', 'y', 'se', 'prepararon', ',', 'con', 'el', 'apoyo',
#         'encubierto', 'de', 'los', 'atenienses', ',', 'a', 'reconquistar',
#         'su', 'ciudad', '.'], dtype=object),
#  array(['Se', 'comunicaron', 'con', 'Epaminondas', ',', 'que', 'comenzó',
#         'a', 'preparar', 'a', 'los', 'jóvenes', 'de', 'la', 'ciudad',
#         'para', 'un', 'intento', 'de', 'asaltar', 'el', 'poder', '.'],
#        dtype=object),
#  array(['En', '379', 'a', '.'], dtype=object),
#  array(['C.', 'un', 'pequeño', 'grupo', 'de', 'exiliados', 'liderados',
#         'por', 'Pelópidas', 'se', 'infiltraron', 'en', 'la', 'ciudad', 'y',
#         'asesinaron', 'a', 'los', 'líderes', 'de', 'el', 'gobierno',
#         'pro-espartano', '.'], dtype=object),
#  array(['Epaminondas', 'y', 'Górgidas', 'dirigieron', 'a', 'un', 'grupo',
#         'de', 'jóvenes', 'que', 'entraron', 'en', 'las', 'armerías', ',',
#         'cogieron', 'armas', ',', 'y', 'rodearon', 'a', 'los',
#         'espartanos', 'en', 'Cadmea', 'asistidos', 'por', 'una', 'fuerza',
#         'de', 'hoplitas', 'atenienses', '.'], dtype=object),
#  array(['En', 'la', 'asamblea', 'tebana', 'celebrada', 'a', 'el', 'día',
#         'siguiente', 'Epaminondas', 'y', 'Górgidas', 'trajeron', 'a',
#         'Pelópidas', 'y', 'a', 'sus', 'hombres', 'frente a', 'la',
#         'audiencia', 'y', 'exhortaron', 'a', 'los', 'tebanos', 'a',
#         'luchar', 'por', 'su', 'libertad', '.'], dtype=object),
#  array(['La', 'asamblea', 'respondió', 'aclamando', 'a', 'Pelópidas', 'y',
#         'a', 'sus', 'hombres', 'como', 'libertadores', 'y', ',',
#         'temiendo', 'por', 'sus', 'vidas', ',', 'la', 'guarnición',
#         'espartana', 'se', 'rindió', 'y', 'fue', 'evacuada', '.'],
#        dtype=object),
#  array(['A', 'los', 'tebanos', 'de', 'el', 'partido', 'pro-espartano',
#         'también', 'se', 'les', 'permitió', 'rendir', 'se', ';', 'fueron',
#         'posteriormente', 'ejecutados', 'por', 'los', 'insurgentes', '.'],
#        dtype=object),
#  array(['Después de', 'el', 'golpe', 'de', 'estado', '.'], dtype=object),
#  array(['Cuando', 'llegaron', 'a', 'Esparta', 'las', 'noticias', 'de',
#         'el', 'levantamiento', 'en', 'Tebas', ',', 'se', 'envió', 'a',
#         'el', 'ejército', 'comandado', 'por', 'Agesilao II', 'para',
#         'someter', 'a', 'la', 'ciudad', '.'], dtype=object),
#  array(['Los', 'tebanos', ',', 'sin', 'embargo', ',', 'decidieron', 'no',
#         'enfrentar', 'se', 'directamente', 'a', 'el', 'ejército',
#         'espartano', 'en', 'el', 'campo', 'de', 'batalla', ',', 'y', 'se',
#         'protegieron', 'tras', 'las', 'murallas', 'de', 'la', 'fortaleza',
#         'de', 'la', 'ciudad', '.'], dtype=object),
#  array(['Los', 'espartanos', 'se', 'dedicaron', 'a', 'saquear', 'la',
#         'zona', 'tratando', 'de', 'hacer', 'salir', 'a', 'los', 'tebanos',
#         ',', 'pero', 'éstos', 'permanecieron', 'en', 'su', 'refugio', 'y',
#         ',', 'finalmente', ',', 'los', 'espartanos', 'se', 'fueron', ',',
#         'con', 'lo', 'que', 'Tebas', 'mantuvo', 'su', 'independencia', '.'],
#        dtype=object),
#  array(['Poco', 'después', 'los', 'tebanos', 'lograron', 'reconstruir',
#         'su', 'antigua', 'confederación', 'de', 'Beocia', 'en', 'una',
#         'nueva', 'forma', 'democrática', '.'], dtype=object),
#  array(['Las', 'ciudades', 'de', 'Beocia', 'se', 'unieron', 'como', 'una',
#         'federación', 'con', 'un', 'consejo', 'ejecutivo', 'formado',
#         'por', 'siete', 'generales', 'o', 'Beotarcas', ',', 'elegidos',
#         'de', 'los', 'siete', 'distritos', 'de', 'Beocia', '.'],
#        dtype=object),
#  array(['La', 'fusión', 'política', 'tuvo', 'tanto', 'éxito', 'que', 'más',
#         'adelante', 'los', 'nombres', 'tebano', 'y', 'beocio', 'se',
#         'usaron', 'indistintamente', 'como', 'muestra', 'de', 'la',
#         'unión', 'de', 'los', 'habitantes', 'de', 'la', 'región', '.'],
#        dtype=object),
#  array(['Buscando', 'acabar', 'con', 'la', 'unión', 'de', 'este', 'nuevo',
#         'estado', ',', 'los', 'espartanos', 'invadieron', 'tres', 'veces',
#         'la', 'zona', 'en', 'los', 'siguientes', 'siete', 'años', '.'],
#        dtype=object),
#  array(['Si', 'bien', 'a', 'el', 'principio', 'se', 'rehuía', 'el',
#         'enfrentamiento', 'directo', ',', 'los', 'beocios', 'poco a poco',
#         'fueron', 'ganando', 'suficiente', 'confianza', 'como', 'para',
#         'salir', 'a', 'el', 'campo', 'abierto', 'y', 'fueron', 'capaces',
#         'de', 'luchar', 'con', 'los', 'espartanos', 'directamente', '.'],
#        dtype=object),
#  array(['Su', 'confianza', 'aumentó', 'mucho', 'más', 'cuando', ',', 'en',
#         '375', 'a', '.'], dtype=object),
#  array(['C.', ',', 'una', 'fuerza', 'de', 'beocios', 'muy', 'superada',
#         'en', 'número', 'logró', ',', 'bajo', 'el', 'mando', 'de',
#         'Pelópidas', ',', 'atravesar', 'el', 'corazón', 'de', 'una',
#         'falange', 'espartana', 'para', 'encontrar', 'una', 'salida',
#         'durante', 'la', 'Batalla de Tegira', '.'], dtype=object),
#  array(['Aunque', 'Esparta', 'continuaba', 'siendo', 'el', 'poder',
#         'supremo', 'griego', 'en', 'el', 'combate', 'terrestre', ',',
#         'los', 'beocios', 'demostraron', 'que', 'ellos', 'también', 'eran',
#         'una', 'amenaza', 'militar', 'creciente', 'y', 'un', 'poder',
#         'político', 'a', 'tener en cuenta', '.'], dtype=object),
#  array(['a', 'el', 'mismo', 'tiempo', ',', 'Pelópidas', ',', 'que',
#         'defendía', 'una', 'política', 'agresiva', 'contra', 'Esparta',
#         ',', 'había', 'logrado', 'colocar', 'se', 'como', 'el',
#         'principal', 'líder', 'político', 'tebano', '.'], dtype=object),
#  array(['En', 'los', 'años', 'siguientes', 'colaboraría', 'extensamente',
#         'con', 'Epaminondas', 'en', 'el', 'diseño', 'de', 'la', 'política',
#         'exterior', 'beocia', '.'], dtype=object),
#  array(['371', 'a', '.'], dtype=object),
#  array(['C.', '.'], dtype=object),
#  array(['Conferencia', 'de', 'paz', 'de', 'el', 'año 371', 'a', '.'],
#        dtype=object),
#  array(['C.', '.'], dtype=object),
#  array(['No', 'existe', 'ninguna', 'fuente', 'que', 'nos', 'indique', 'en',
#         'qué', 'momento', 'fue', 'elegido', 'Epaminondas', 'como',
#         'Beotarca', 'por', 'primera', 'vez', ',', 'pero', 'en', 'el',
#         'año 371', 'a', '.'], dtype=object),
#  array(['C.', 'ocupaba', 'el', 'puesto', 'y', ',', 'el', 'año',
#         'siguiente', ',', 'estaba', 'a', 'la', 'cabeza', 'de', 'una',
#         'conferencia', 'de', 'paz', 'que', 'tuvo lugar', 'en', 'Esparta',
#         '.'], dtype=object),
#  array(['Se', 'había', 'hecho', 'un', 'débil', 'intento', 'de', 'lograr',
#         'una', 'Paz Común', 'en', '375', 'a', '.'], dtype=object),
#  array(['C.', 'pero', 'la', 'guerra', 'entre', 'Atenas', 'y', 'Esparta',
#         'había', 'resurgido', 'ya', 'en', '373', 'a', '.'], dtype=object),
#  array(['C. Tebas', ',', 'mientras', 'tanto', ',', 'estaba',
#         'fortaleciendo', 'su', 'confederación', '.'], dtype=object),
#  array(['En', 'el', 'año 371', 'Atenas', 'y', 'Esparta', 'volvían', 'a',
#         'estar', 'preocupadas', 'por', 'la', 'guerra', ',', 'por', 'lo',
#         'que', 'tuvo lugar', 'la', 'conferencia', 'de', 'paz', '.'],
#        dtype=object),
#  array(['En', 'ella', ',', 'Epaminondas', 'provocó', 'una', 'importante',
#         'ruptura', 'con', 'Esparta', 'cuando', 'insistió', 'en', 'firmar',
#         'no sólo', 'en', 'nombre', 'de', 'los', 'tebanos', ',', 'sino',
#         'en', 'el', 'de', 'todos', 'los', 'beocios', '.'], dtype=object),
#  array(['Agesilao II', 'se', 'negó', 'a', 'permitir', 'lo', ',',
#         'insistiendo', 'en', 'que', 'las', 'ciudades', 'de', 'Beocia',
#         'deberían', 'ser', 'independientes', ',', 'pero', 'Epaminondas',
#         'contraargumentó', 'que', 'si', 'eso', 'fuese', 'así', ',',
#         'entonces', 'las', 'ciudades', 'de', 'Laconia', 'deberían', 'ser',
#         'lo', 'también', '.'], dtype=object),
#  array(['Ante', 'esta', 'situación', ',', 'Agesilao', 'expulsó', 'a',
#         'los', 'tebanos', 'de', 'la', 'conferencia', 'y', 'de', 'el',
#         'tratado', ',', 'por', 'lo', 'que', 'la', 'delegación', 'volvió',
#         'a', 'Tebas', 'y', 'ambos', 'bandos', 'se', 'prepararon', 'para',
#         'la', 'guerra', '.'], dtype=object),
#  ...]

# %%
# Now creates a dataframe with the list of numpy array
# Each array is a row
sentences_df = pd.DataFrame(sentences_array)
sentences_df
# Out:
#                 0            1          2                3             4     \
# 0           Arequipa           es         el           nombre            de
# 1           Conocido  previamente        con               la   designación
# 2       ENDOFARTICLE            .       None             None          None
# 3                 La    provincia         de          Teherán             (
# 4              Tiene          una  extensión               de  alrededor de
# ...              ...          ...        ...              ...           ...
# 199085  Generalmente          los   gigantes         desfilan            en
# 199086           Los      pueblos      ricos           tienen           más
# 199087  Generalmente          las    figuras      representan    arquetipos
# 199088       Enlaces     externos          .             None          None
# 199089            La      giganta         de  Stephanie Evans             ;
#
#                 5          6         7     8          9     ...  1483  1484  \
# 0                 el  asteroide    número   737         de  ...  None  None
# 1        provisional       1912        QB     y         la  ...  None  None
# 2               None       None      None  None       None  ...  None  None
# 3              Farsi          :         )    es        una  ...  None  None
# 4             18.637        km²         y    se  encuentra  ...  None  None
# ...              ...        ...       ...   ...        ...  ...   ...   ...
# 199085       parejas         de   gigante     y    giganta  ...  None  None
# 199086            de        una    pareja     .       None  ...  None  None
# 199087     populares          ,  tal como    el    burgués  ...  None  None
# 199088          None       None      None  None       None  ...  None  None
# 199089  ENDOFARTICLE          .      None  None       None  ...  None  None
#
#         1485  1486  1487  1488  1489  1490  1491  1492
# 0       None  None  None  None  None  None  None  None
# 1       None  None  None  None  None  None  None  None
# 2       None  None  None  None  None  None  None  None
# 3       None  None  None  None  None  None  None  None
# 4       None  None  None  None  None  None  None  None
# ...      ...   ...   ...   ...   ...   ...   ...   ...
# 199085  None  None  None  None  None  None  None  None
# 199086  None  None  None  None  None  None  None  None
# 199087  None  None  None  None  None  None  None  None
# 199088  None  None  None  None  None  None  None  None
# 199089  None  None  None  None  None  None  None  None
#
# [199090 rows x 1493 columns]
